# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

from pathlib import Path
from sklearn.linear_model import LogisticRegression

# %%
PATH = Path("/data2/yinterian/microarray/")
PATH_data = PATH/"Datasets_before_gene_ranked"

# %%
def split_train_val_test(df, seed=23):
    seed = 23
    np.random.seed(seed)
    n = int(0.1*len(df))
    N = len(df) - 2*n
    train_mask = np.array(2*n*[False] + N*[True])
    np.random.shuffle(train_mask)
    train = df[train_mask].copy()
    test_valid = df[~train_mask].copy()
    test_mask = np.array(n*[False] + n*[True])
    np.random.shuffle(test_mask)
    test = test_valid[test_mask].copy()
    valid = test_valid[~test_mask].copy()
    return train, valid, test

# %%
def clean_target(df, target_index=978):
    y_agg = df.iloc[:, target_index].value_counts()
    max_index = y_agg.argmax()
    class_label = y_agg.index[0] 
    target = df.iloc[:, target_index].values
    df = df.iloc[:,:target_index].copy()
    df["target"] = np.array([1 if (x == class_label) else 0 for x in target])
    return df

# %%
def univ_predictions(train, valid, test, target_index=978):
    train_prob = np.zeros((train.shape[0], target_index))
    valid_prob = np.zeros((valid.shape[0], target_index))
    test_prob = np.zeros((test.shape[0], target_index))
    y_train = train.target.values
    for i in range(target_index):
        X_train = train.iloc[:,i].values.reshape(-1, 1)
        X_valid = valid.iloc[:,i].values.reshape(-1, 1)
        X_test = test.iloc[:,i].values.reshape(-1, 1)
        clf = LogisticRegression(random_state=0).fit(X_train, y_train)
        train_prob[:,i] = clf.predict_proba(X_train)[:, 1]
        valid_prob[:,i] = clf.predict_proba(X_valid)[:, 1]
        test_prob[:,i] = clf.predict_proba(X_test)[:, 1]
    
    return train_prob, valid_prob, test_prob

# %%
def prob2rank(train_prob, valid_prob, test_prob):
    q = np.quantile(train_prob, 0.1*np.arange(0,11))
    train_rank = 0.1*np.searchsorted(q, train_prob)
    valid_rank = 0.1*np.searchsorted(q, valid_prob)
    test_rank = 0.1*np.searchsorted(q, test_prob)
    return train_rank, valid_rank, test_rank

# %%
def pipeline(path, target_index=978):
    df = pd.read_csv(f_csv)
    df = clean_target(df)
    # replace 0s by nan
    df.iloc[:,:target_index] = df.iloc[:,:target_index].replace([0], np.nan)
    # if we see negative numbers we make them positive
    if min(df.min(skipna=True, axis=1)) < 0:
        min_row = df.min(skipna=True, axis=1)
        df.iloc[:, :target_index] = df.iloc[:, :target_index].add(-min_row + 1e-4, axis=0)
    # divide by median per row
    med = df.median(axis=1)
    df.iloc[:, :target_index] = df.iloc[:, :target_index].div(med, axis=0)
    df.iloc[:,:target_index] = df.iloc[:,:target_index].replace([np.nan], 0)
    train, valid, test = split_train_val_test(df)
    # compute masks
    train_mask = (train.iloc[:,:target_index].values > 0).astype(int)
    valid_mask = (valid.iloc[:,:target_index].values > 0).astype(int)
    test_mask = (test.iloc[:,:target_index].values > 0).astype(int)
    
    train_prob, valid_prob, test_prob = univ_predictions(train, valid, test)
    train_rank, valid_rank, test_rank = prob2rank(train_prob*train_mask, valid_prob*valid_mask, test_prob*test_mask)
    train.iloc[:,:target_index] = train_rank
    valid.iloc[:,:target_index] = valid_rank
    test.iloc[:,:target_index] = test_rank
    return train, valid, test

# %%
PATH_out = PATH/"ranked_datasets/"
for f in PATH_data.iterdir():
    f_csv = [x for x in f.iterdir()][0]
    f_name = f_csv.name.replace(" ", "")
    f_train = PATH_out/"train_{}".format(f_name) 
    if not f_train.is_file():
        print(f_csv, f_name)
        train, valid, test = pipeline(f_csv)
        print(train.shape)
        train.to_csv(PATH_out/"train_{}".format(f_name))
        valid.to_csv(PATH_out/"valid_{}".format(f_name))
        test.to_csv(PATH_out/"test_{}".format(f_name))
# Out:
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE14814/GSE14814_gene_profile.csv GSE14814_gene_profile.csv
# (107, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE7670/GSE7670_gene_profile.csv GSE7670_gene_profile.csv
# (54, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE67916/GSE67916_gene_profile.csv GSE67916_gene_profile.csv
# (16, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/ GDS2250/ GDS2250_gene_profile.csv GDS2250_gene_profile.csv
# (39, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE75316/GSE75316_gene_profile.csv GSE75316_gene_profile.csv
# (49, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE36076/GSE36076_gene_profile.csv GSE36076_gene_profile.csv
# (22, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE37745/GSE37745_gene_profile.csv GSE37745_gene_profile.csv
# (158, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE16795/GSE16795_gene_profile.csv GSE16795_gene_profile.csv
# (33, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE71363/GSE71363_gene_profile.csv GSE71363_gene_profile.csv
# (16, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE24514/GSE24514_gene_profile.csv GSE24514_gene_profile.csv
# (41, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE9936/GSE9936_gene_profile.csv GSE9936_gene_profile.csv
# (85, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE129551/GSE129551_gene_profile.csv GSE129551_gene_profile.csv
# (119, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE4554/GSE4554_gene_profile.csv GSE4554_gene_profile.csv
# (68, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE8977/GSE8977_gene_profile.csv GSE8977_gene_profile.csv
# (18, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE13309/GSE13309_gene_profile.csv GSE13309_gene_profile.csv
# (20, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE25487/GSE25487_gene_profile.csv GSE25487_gene_profile.csv
# (17, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE23640/GSE23640_gene_profile.csv GSE23640_gene_profile.csv
# (12, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE32701/GSE32701_gene_profile.csv GSE32701_gene_profile.csv
# (32, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/ GDS3945/ GDS3945_gene_profile.csv GDS3945_gene_profile.csv
# (34, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE40654/GSE40654_gene_profile.csv GSE40654_gene_profile.csv
# (20, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/ GDS1887/ GDS1887_gene_profile.csv GDS1887_gene_profile.csv
# (38, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE35452/GSE35452_gene_profile.csv GSE35452_gene_profile.csv
# (38, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE69657/GSE69657_gene_profile.csv GSE69657_gene_profile.csv
# (24, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/ GDS4664/ GDS4664_gene_profile.csv GDS4664_gene_profile.csv
# (33, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE20854/GSE20854_gene_profile.csv GSE20854_gene_profile.csv
# (20, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE40595/GSE40595_gene_profile.csv GSE40595_gene_profile.csv
# (63, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE110224/GSE110224_gene_profile.csv GSE110224_gene_profile.csv
# (28, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE72970/GSE72970_gene_profile.csv GSE72970_gene_profile.csv
# (100, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE38129/GSE38129_gene_profile.csv GSE38129_gene_profile.csv
# (48, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/ GDS2546/ GDS2546_gene_profile.csv GDS2546_gene_profile.csv
# (135, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/ GDS1732/ GDS1732_gene_profile.csv GDS1732_gene_profile.csv
# (12, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/ GDS
 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE85570/GSE85570_gene_profile.csv GSE85570_gene_profile.csv
# (352, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/ GDS2298/ GDS2298_gene_profile.csv GDS2298_gene_profile.csv
# (16, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/ GDS5268/ GDS5268_gene_profile.csv GDS5268_gene_profile.csv
# (60, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE8401/GSE8401_gene_profile.csv GSE8401_gene_profile.csv
# (67, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/ GDS2785/ GDS2785_gene_profile.csv GDS2785_gene_profile.csv
# (35, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE34112/GSE34112_gene_profile.csv GSE34112_gene_profile.csv
# (14, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE48433/GSE48433_gene_profile.csv GSE48433_gene_profile.csv
# (659, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/ GDS806/ GDS806_gene_profile.csv GDS806_gene_profile.csv
# (48, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE50830/GSE50830_gene_profile.csv GSE50830_gene_profile.csv
# (136, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE27431/GSE27431_gene_profile.csv GSE27431_gene_profile.csv
# (24, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/ GDS3836/ GDS3836_gene_profile.csv GDS3836_gene_profile.csv
# (18, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE27914/GSE27914_gene_profile.csv GSE27914_gene_profile.csv
# (25, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GDS4053/ GDS4053_gene_profile.csv GDS4053_gene_profile.csv
# (35, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/ GDS4345/ GDS4345_gene_profile.csv GDS4345_gene_profile.csv
# (24, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE58792/GSE58792_gene_profile.csv GSE58792_gene_profile.csv
# (41, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE33532/GSE33532_gene_profile.csv GSE33532_gene_profile.csv
# (80, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE46106/GSE46106_gene_profile.csv GSE46106_gene_profile.csv
# (36, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE66305/GSE66305_gene_profile.csv GSE66305_gene_profile.csv
# (72, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE19697/GSE19697_gene_profile.csv GSE19697_gene_profile.csv
# (20, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE13548/GSE13548_gene_profile.csv GSE13548_gene_profile.csv
# (34, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE77803/GSE77803_gene_profile.csv GSE77803_gene_profile.csv
# (126, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE13787/GSE13787_gene_profile.csv GSE13787_gene_profile.csv
# (19, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE37964/GSE37964_gene_profile.csv GSE37964_gene_profile.csv
# (36, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/ GDS845/ GDS845_gene_profile.csv GDS845_gene_profile.csv
# (16, 979)
# /data2/yinterian/microarray/Datasets_before_gene_ranked/GSE3678/GSE3678_gene_profile.csv GSE3678_gene_profile.csv
# (12, 979)

# %%
PATH_data2 = PATH/"ranked_datasets/"

training_files = list(PATH_data2.glob('train_*'))
valid_files = list(PATH_data2.glob('valid_*'))
test_files = list(PATH_data2.glob('test_*'))

# %%
problem_ids = [f.name.split("_")[1] for f in training_files]
problem2index = {v:k  for k,v in enumerate(problem_ids)}
len(problem_ids)
# Out:
# 552

# %%
def make_master_df(files):
    dfs = []
    for f in files:
        df = pd.read_csv(f)
        problem = f.name.split("_")[1]
        df["index"] = problem2index[problem]
        dfs.append(df)
    df = pd.concat(dfs)
    df = df.drop(columns=["Unnamed: 0"])
    return df

# %%
df = make_master_df(training_files)

# %%
df.shape
# Out:
# (32066, 980)

# %%
df.to_csv(PATH/"train_all_problems.csv", index=False)

# %%
df = make_master_df(valid_files)
df.shape
# Out:
# (3725, 980)

# %%
df.to_csv(PATH/"valid_all_problems.csv", index=False)

# %%
df = make_master_df(test_files)
df.shape
# Out:
# (3725, 980)

# %%
df.to_csv(PATH/"test_all_problems.csv", index=False)
